# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aangelopoulos/conformal-prediction/blob/main/notebooks/weather-time-series-distribution-shift.ipynb)

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import seaborn as sns
from tqdm import tqdm
from scipy.optimize import brentq
# !pip install -U --no-cache-dir gdown --pre
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Collecting gdown
#   Downloading gdown-6.0.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.4.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-6.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.2.2
#     Uninstalling gdown-5.2.2:
#       Successfully uninstalled gdown-5.2.2
# Successfully installed gdown-6.0.0

# %%
# Load cached data from Shifts (Yandex Weather Prediction). See https://github.com/Shifts-Project/shifts for details.
# The data has a change point halfway through.
if not os.path.exists('../data'):
    os.system('gdown 1h7S6N_Rx7gdfO3ZunzErZy6H7620EbZK -O ../data.tar.gz')
    os.system('tar -xf ../data.tar.gz -C ../')
    os.system('rm ../data.tar.gz')

data = np.load('../data/weather/weather-catboost.npz')
preds = data['preds'][:,::1,:]  # model predictions from an ensemble of CatBoost models
temperatures = data['temperatures'][::1] # True Temperature (degrees Celsius)
times = data['times'][::1] # Times

pred_mean = preds[:,:,0].mean(axis=0) # average prediction of these models as the base model fˆ.
pred_uncertainty = np.sqrt(preds[:,:,1].mean(axis=0)) # average of these variances as our uncertainty scalar u^(Xt​)

# Moving average helper: Visualize the average accuracy
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

print(times)
sort_idx = np.argsort(times) # give indices that sort the time
print(sort_idx)
pred_mean = pred_mean[sort_idx]
temperatures = temperatures[sort_idx]
times = times[sort_idx]
pred_uncertainty = pred_uncertainty[sort_idx]
# Out:
# [1539162000 1545006600 1540094400 ... 1566777600 1563156600 1563228000]
# [ 1813 17103 45621 ... 76316 90151 52119]

# %%
# Problem setup
alpha = 0.1 # 1-alpha is the desired coverage
K=1000;  # Take a fixed window of K (Use the most recent 1000 past scores)
weights = np.ones((K,));  #This means all points inside the recent window get equal weight: 1
wtildes = weights/(weights.sum() + 1) # normalzied w: w~i​= 1/1000+1​

# %% [markdown]
# ### Weighted conformal prediction happens here

# %%
# Use the uncertainty scalars method to get conformal scores
scores = np.abs(pred_mean-temperatures)/pred_uncertainty # st​=∣Yt​−f^​(Xt​)∣​/u^(Xt​)
# Get the weighted score quantile at each time step
def get_weighted_quantile(scores,T):
    score_window = scores[T-K:T] # For time T, this takes the most recent K scores: sT−K​,...,sT−1​
    def critical_point_quantile(q): return (wtildes * (score_window <= q)).sum() - (1 - alpha) # q^: Find q such that about 90% of the weighted recent scores are below q.
    return brentq(critical_point_quantile, 0, 100) # This finds the value of q where the function equals zero.
# Compute q ^ ​ t ​ for every time step: For each time point after the first 1000 points, compute a new conformal threshold.
qhats = np.array( [get_weighted_quantile(scores, t) for t in range(K+1, scores.shape[0])] )
# Deploy (output=lower and upper adjusted quantiles): C(xt​)=[f^​(xt​)−q^​t​u^(xt​),f^​(xt​)+q^​t​u^(xt​)]
prediction_sets = [pred_mean[K+1:] - pred_uncertainty[K+1:]*qhats, pred_mean[K+1:] + pred_uncertainty[K+1:]*qhats]

# %%
# For comparison, run naive conformal baseline: usual q^ equaiton
naive_qhats = np.array( [np.quantile(scores[:t], np.ceil((t+1)*(1-alpha))/t, interpolation='higher') for t in range(K+1, scores.shape[0]) ] )
naive_prediction_sets = [pred_mean[K+1:] - pred_uncertainty[K+1:]*naive_qhats, pred_mean[K+1:] + pred_uncertainty[K+1:]*naive_qhats]

# %%
# Calculate coverage over time: This checks whether the true temperature is inside the weighted conformal interval.
covered = ( temperatures[K+1:] >= prediction_sets[0] ) & ( temperatures[K+1:] <= prediction_sets[1] )
coverage_over_time = moving_average(covered, 500) # This smooths coverage over a rolling 500-time-step window.
naive_covered = ( temperatures[K+1:] >= naive_prediction_sets[0] ) & ( temperatures[K+1:] <= naive_prediction_sets[1] )
naive_coverage_over_time = moving_average(naive_covered, 500)

# %%
# Plot prediction sets and coverage over time
plt.rcParams.update({'font.size': 12})
fig, axs = plt.subplots(1,2,figsize=(12,3))

axs[0].plot(coverage_over_time, label='weighted');
axs[0].plot(naive_coverage_over_time, label='unweighted');
sns.despine(ax=axs[0],top=True,right=True)
axs[0].set_xlabel('timestamp')
axs[0].set_ylabel(f'coverage\n(size 500 sliding window)')
axs[0].legend()

start_point = 99700
timestamps = np.array(range(start_point,pred_mean[K+1:].shape[0]+K+1))
axs[1].plot(timestamps,pred_mean[start_point:],color='#00000033',label='prediction')
axs[1].plot(timestamps,temperatures[start_point:],color='#00FF0066', label='ground truth')
sns.despine(ax=axs[1],top=True,right=True)
axs[1].fill_between(timestamps, prediction_sets[0][start_point-K-1:], prediction_sets[1][start_point-K-1:], color='#0000FF11', label='weighted conformal interval');
axs[1].set_ylim(0,50);
axs[1].locator_params(tight=True, nbins=4)
axs[1].set_xlabel('timestamp')
axs[1].set_ylabel(r'temperature ($^\circ C$)')
axs[1].legend(loc='upper right');
plt.tight_layout()

plt.savefig('../data/weather/weather-results.pdf',)

# %% [markdown]
# This method was first introduced here: https://arxiv.org/abs/2202.13415.
